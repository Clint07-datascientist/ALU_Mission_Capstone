# %% [markdown]
# <a href="https://colab.research.google.com/github/Clint07-datascientist/ALU_Mission_Capstone/blob/main/Machine_Learning_Pipeline/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi uvicorn nest-asyncio pydantic
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (0.133.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.41.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.12.3)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.52.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.41.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette>=0.40.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette>=0.40.0->fastapi) (3.11)

# %%
# Importing all the necessary libraries
import os
import kagglehub
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from fastapi import FastAPI, File, Form, UploadFile
import nest_asyncio
import threading
from pydantic import BaseModel
import time
from google.colab import output, files
import uvicorn
import seaborn as sns
from PIL import Image
import io
import socket

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Paste your API token from the Kaggle popup here
os.environ["KAGGLE_API_TOKEN"] = "KGAT_2b013b5dcbafb2b8d60c189cfe8aa563"

print("Kaggle API Token configured!")
# Out:
# Kaggle API Token configured!

# %%
# 2. Download the dataset
print("Downloading JMuBEN dataset...")
dataset_path = kagglehub.dataset_download("noamaanabdulazeem/jmuben-coffee-dataset")

print(f"Dataset downloaded successfully to: {dataset_path}")

# 3. Verify the contents to see the folder structure
print("\nFolders inside the dataset:")
print(os.listdir(dataset_path))
# Out:
# Downloading JMuBEN dataset...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/noamaanabdulazeem/jmuben-coffee-dataset?dataset_version_number=2...
# 100%|██████████| 773M/773M [00:37<00:00, 21.6MB/s]
# Extracting files...
# Dataset downloaded successfully to: /root/.cache/kagglehub/datasets/noamaanabdulazeem/jmuben-coffee-dataset/versions/2
#
# Folders inside the dataset:
# ['JMuBEN']

# %%
# 1. Define your parameters
batch_size = 16
img_height = 224 # Required input size for MobileNetV3
img_width = 224

# 2. Only load the classes relevant to my Capstone scope
target_classes = ['Healthy', 'Leaf rust', 'Miner'] # Corrected capitalization for 'Leaf rust' again

# Adjust dataset_path to point to the correct subdirectory
import os
full_dataset_path = os.path.join(dataset_path, 'JMuBEN')

print("Loading Training Data...")
print(f"Target classes being used: {target_classes}") # Added print statement to verify target_classes
train_ds = tf.keras.utils.image_dataset_from_directory(
  full_dataset_path, # This is the corrected variable
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  class_names=target_classes # This automatically filters out Phoma and Cerscospora!
)

print("\nLoading Validation Data...")
print(f"Target classes being used: {target_classes}") # Added print statement to verify target_classes
val_ds = tf.keras.utils.image_dataset_from_directory(
  full_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  class_names=target_classes
)

# 3. Optimize for performance (Safely streaming from disk to prevent RAM crash)
AUTOTUNE = tf.data.AUTOTUNE

# .cache() has been removed!
train_ds = train_ds.shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

print("\nData Pipeline Ready (RAM Safe)!")
# Out:
# Loading Training Data...
# Target classes being used: ['Healthy', 'Leaf rust', 'Miner']
# Found 44297 files belonging to 3 classes.
# Using 35438 files for training.
#
# Loading Validation Data...
# Target classes being used: ['Healthy', 'Leaf rust', 'Miner']
# Found 44297 files belonging to 3 classes.
# Using 8859 files for validation.
#
# Data Pipeline Ready (RAM Safe)!

# %%
# ---------------------------------------------------------
# VISUALIZATION 1: 3x3 Sample Image Grid
# ---------------------------------------------------------
print("Generating Image Sample Grid...")
plt.figure(figsize=(10, 10))
# Fix: Use target_classes directly as train_ds loses class_names after caching/prefetching
class_names = target_classes

# Track how many images of each class we've plotted
plotted_counts = {name: 0 for name in class_names}

# Scan through the dataset to find exactly 3 of each class
for images, labels in train_ds.unbatch().take(500):
    class_name = class_names[labels.numpy()]

    if plotted_counts[class_name] < 3:
        # Calculate grid position: Row = class index, Col = current count
        row = class_names.index(class_name)
        col = plotted_counts[class_name]
        position = (row * 3) + col + 1

        ax = plt.subplot(3, 3, position)
        plt.imshow(images.numpy().astype("uint8"))
        plt.title(f"{class_name}", fontsize=14)
        plt.axis("off")

        plotted_counts[class_name] += 1

    # Stop searching once we have 3 of each
    if all(count == 3 for count in plotted_counts.values()):
        break

plt.tight_layout()
plt.show()
# Out:
# Generating Image Sample Grid...

# %%
# ---------------------------------------------------------
# VISUALIZATION 2: Class Distribution Bar Chart
# ---------------------------------------------------------
print("\nGenerating Class Distribution Chart...")

class_counts = []
for class_name in target_classes:
    # Correct the path: dataset_path points to the root,
    # but images are in JMuBEN/class_name
    folder_path = os.path.join(full_dataset_path, class_name)
    count = len(os.listdir(folder_path))
    class_counts.append(count)

plt.figure(figsize=(8, 5))
bars = plt.bar(target_classes, class_counts, color=['#2ca02c', '#d62728', '#1f77b4'])

# Add the exact numbers on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 50, int(yval), va='bottom', ha='center', fontsize=12)

plt.title('Image Distribution for AgroInsight Target Classes', fontsize=14)
plt.xlabel('Coffee Leaf Condition', fontsize=12)
plt.ylabel('Number of Images', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Generating Class Distribution Chart...

# %%
# ---------------------------------------------------------
# MODEL ARCHITECTURE: MobileNetV3 (Small)
# ---------------------------------------------------------
print("Building MobileNetV3 Transfer Learning Model...")

# 1. Load the pre-trained base model (without the top classification layer)
base_model = tf.keras.applications.MobileNetV3Small(
    input_shape=(img_height, img_width, 3),
    include_top=False,
    weights='imagenet'
)

# 2. Freeze the base model to prevent destroying pre-trained weights during initial training
base_model.trainable = False

# 3. Add the custom classification head for AgroInsight
model = tf.keras.Sequential([
    # Add data augmentation to prevent overfitting
    tf.keras.layers.RandomFlip('horizontal_and_vertical', input_shape=(img_height, img_width, 3)),
    tf.keras.layers.RandomRotation(0.2),

    # Base Model
    base_model,

    # Flatten the features using Global Average Pooling (more efficient than standard Flatten)
    tf.keras.layers.GlobalAveragePooling2D(),

    # Dense hidden layer with Dropout
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2), # Drops 20% of neurons to prevent memorization

    # Output layer (3 neurons for Healthy, Leaf rust, Miner)
    tf.keras.layers.Dense(3, activation='softmax')
])

# 4. Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
model.summary()
# Out:
# Building MobileNetV3 Transfer Learning Model...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV3Small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 576)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,013,363 (3.87 MB)
#  Trainable params: 74,243 (290.01 KB)
#  Non-trainable params: 939,120 (3.58 MB)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# ---------------------------------------------------------
# INITIAL PERFORMANCE METRICS WITH EARLY STOPPING
# ---------------------------------------------------------

# 1. Define the Early Stopping rule
early_stop = EarlyStopping(
    monitor='val_loss',        # Watch the validation loss for improvements
    patience=3,                # If it doesn't improve for 3 consecutive epochs, stop!
    restore_best_weights=True  # Automatically keep the best model, not the last model
)

# Safely set a high maximum epoch count
epochs = 20

print(f"Training Model for up to {epochs} epochs...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stop]     # Inject the rule into the training loop
)

# Extract predictions for the validation set
print("\nGenerating Classification Report and Confusion Matrix...")
y_pred = []
y_true = []

# Iterate through validation data to get true labels and predict
for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

# 1. Print Accuracy, Precision, Recall, F1-Score
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=target_classes))

# 2. Plot Confusion Matrix Heatmap
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=target_classes,
            yticklabels=target_classes)
plt.title('Validation Confusion Matrix', fontsize=14)
plt.xlabel('Predicted Diagnosis', fontsize=12)
plt.ylabel('Actual Diagnosis', fontsize=12)
plt.show()

# 3. Plot Training vs Validation Accuracy
plt.figure(figsize=(8, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Initial Training Accuracy over 5 Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training Model for up to 20 epochs...
# Epoch 1/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 34s 11ms/step - accuracy: 0.9884 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 1.9338e-05
# Epoch 2/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 1.0000 - loss: 1.7548e-05 - val_accuracy: 1.0000 - val_loss: 1.0408e-05
# Epoch 3/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 1.0000 - loss: 1.2803e-05 - val_accuracy: 1.0000 - val_loss: 1.3725e-04
# Epoch 4/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 2.7457e-04
# Epoch 5/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 1.0000 - loss: 1.5279e-05 - val_accuracy: 1.0000 - val_loss: 2.2389e-06
# Epoch 6/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.9999 - loss: 3.4686e-04 - val_accuracy: 0.9999 - val_loss: 2.9317e-04
# Epoch 7/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 1.0000 - loss: 1.6349e-05 - val_accuracy: 1.0000 - val_loss: 2.4221e-10
# Epoch 8/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.9997 - loss: 7.2492e-04 - val_accuracy: 0.9974 - val_loss: 0.0120
# Epoch 9/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.9998 - loss: 7.4665e-04 - val_accuracy: 1.0000 - val_loss: 4.7100e-06
# Epoch 10/20
# 2215/2215 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 3.6870e-09
#
# Generating Classification Report and Confusion Matrix...
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00      3874
#    Leaf rust       1.00      1.00      1.00      1621
#        Miner       1.00      1.00      1.00      3364
#
#     accuracy                           1.00      8859
#    macro avg       1.00      1.00      1.00      8859
# weighted avg       1.00      1.00      1.00      8859

# %%
# ---------------------------------------------------------
# DEPLOYMENT OPTION: API Mockup (FastAPI / Swagger UI)
# ---------------------------------------------------------
# We use %%writefile to save this script as app.py.
# In a real deployment (e.g., on a cloud server or local testing),
# running `uvicorn app:app --reload` will automatically generate a Swagger UI at /docs

# ---------------------------------------------------------
# DEPLOYMENT OPTION: API Mockup (FastAPI / Swagger UI)
# ---------------------------------------------------------

# 1. Initialize the API
app = FastAPI(
    title="AgroInsight Edge API (Real Inference)",
    description="Interactive Swagger UI that runs real MobileNetV3 predictions on uploaded coffee leaf images.",
    version="1.0.0"
)

# IMPORTANT: Ensure this matches the exact order of your train_ds.class_names!
CLASS_NAMES = ['Healthy', 'Leaf rust', 'Miner']
# IMPORTANT: Ensure this matches the image size you used to train the model!
IMG_SIZE = (224, 224)

# 2. Create the POST endpoint
@app.post("/api/v1/diagnose", tags=["Inference"])
async def run_inference(
    file: UploadFile = File(...),
    farm_location: str = Form("Rutsiro"),
    hardware_id: str = Form("Probe-001")
):
    try:
        # A. Read the uploaded file bytes
        image_bytes = await file.read()

        # B. Preprocess the image for the neural network
        img = Image.open(io.BytesIO(image_bytes))

        # Convert to RGB (removes alpha channels if the user uploads a PNG)
        if img.mode != "RGB":
            img = img.convert("RGB")

        # Resize to match the model's expected input
        img = img.resize(IMG_SIZE)

        # Convert the image to a NumPy array
        img_array = tf.keras.preprocessing.image.img_to_array(img)

        # Expand dimensions to create a "batch" of 1
        img_array = tf.expand_dims(img_array, 0)

        # -----------------------------------------------------
        # -----------------------------------------------------
        # THE FIX: Native MobileNetV3 Preprocessing
        # -----------------------------------------------------
        from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
        img_array = preprocess_input(img_array)

        # C. Run the real inference through your trained model!
        predictions = model.predict(img_array)

        # D. Extract the highest probability class
        predicted_index = np.argmax(predictions[0])
        predicted_class = CLASS_NAMES[predicted_index]
        confidence_score = float(np.max(predictions[0]))

        return {
            "status": "success",
            "timestamp": time.time(),
            "device": hardware_id,
            "location": farm_location,
            "filename_received": file.filename,
            "inference_results": {
                "disease_class": predicted_class,
                "confidence_score": round(confidence_score, 4),
                "model_version": "MobileNetV3_Quantized_v1"
            },
            "message": "Real inference executed successfully."
        }

    except Exception as e:
        # If the user uploads a corrupted file or something breaks, the API won't crash
        return {"status": "error", "message": str(e)}

# 3. Dynamic Port Finder
def get_free_port():
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind(("", 0))
        return s.getsockname()[1]

FREE_PORT = get_free_port()

# 4. Background execution setup
def start_server():
    nest_asyncio.apply()
    uvicorn.run(app, host="127.0.0.1", port=FREE_PORT, log_level="error")

api_thread = threading.Thread(target=start_server, daemon=True)
api_thread.start()
time.sleep(2)

# 5. Generate the public Colab URL to view the Swagger UI
print(f"✅ API Server successfully started on fresh port: {FREE_PORT}")
print("Click the link below to open your interactive Swagger UI:")
output.serve_kernel_port_as_window(FREE_PORT, path='/docs')
# Out:
# ✅ API Server successfully started on fresh port: 45245
# Click the link below to open your interactive Swagger UI:
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.

# %%
# Prints the exact class order the model learned
print("Model learned this exact order:", target_classes)
# Out:
# Model learned this exact order: ['Healthy', 'Leaf rust', 'Miner']

# %%
# 1. Load the exact same image that failed in the API
# (Ensure the file is uploaded to your Colab workspace)
img_path = "/healthy01.jfif"
img = Image.open(img_path).convert("RGB").resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# 2. Test A: Raw Pixels (No preprocessing, 0 to 255)
raw_pred = model.predict(img_array, verbose=0)
print("\nTEST A - RAW PIXEL ARRAY:", raw_pred)

# 3. Test B: Standard Keras Scaling (0.0 to 1.0)
scaled_pred = model.predict(img_array / 255.0, verbose=0)
print("TEST B - SCALED PIXEL ARRAY:", scaled_pred)

# 4. Test C: MobileNetV3 Native Preprocessing (-1.0 to 1.0)
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
native_pred = model.predict(preprocess_input(np.copy(img_array)), verbose=0)
print("TEST C - NATIVE PREPROCESSING ARRAY:", native_pred)
# Out:
# TEST A - RAW PIXEL ARRAY: [[1.7601320e-13 5.9458513e-19 1.0000000e+00]]
# TEST B - SCALED PIXEL ARRAY: [[3.9320796e-09 1.0000000e+00 4.8227689e-09]]
# TEST C - NATIVE PREPROCESSING ARRAY: [[1.7601320e-13 5.9458513e-19 1.0000000e+00]]

# %%
# 1. Grab exactly one batch of data from your validation set
for images, labels in val_ds.take(1):

    # 2. Search through the batch for a "Healthy" leaf (Index 0)
    for i in range(len(labels)):
        # Check if the true label is 'Healthy'
        if np.argmax(labels[i].numpy()) == 0:

            # 3. Convert the TensorFlow array back into a normal picture
            img_to_save = tf.keras.preprocessing.image.array_to_img(images[i])
            img_to_save.save("JMuBEN_healthy_test.jpg")
            print("✅ Successfully saved 'JMuBEN_healthy_test.jpg' to your Colab files!")
            break

    break # Stop after finding the first one
# Out:
# ✅ Successfully saved 'JMuBEN_healthy_test.jpg' to your Colab files!

# %%
# ---------------------------------------------------------
# EDGE DEPLOYMENT: TFLite Conversion & Quantization
# ---------------------------------------------------------
print("Initializing TFLite Converter...")

# 1. Load your trained model into the converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 2. Apply Dynamic Range Quantization
# This is the crucial step for the Raspberry Pi Zero 2 W
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 3. Execute the conversion
print("Compressing and converting to .tflite format (this may take a minute)...")
tflite_model = converter.convert()

# 4. Save the file to your Colab instance
tflite_filename = 'agroinsight_mobilenetv3_quantized.tflite'
with open(tflite_filename, 'wb') as f:
    f.write(tflite_model)

print(f"\n✅ Success! Edge-AI model saved as: {tflite_filename}")

# 5. Automatically download the file to your physical machine
print("Downloading to your computer...")
files.download(tflite_filename)
# Out:
# Initializing TFLite Converter...
# Compressing and converting to .tflite format (this may take a minute)...
# Saved artifact at '/tmp/tmpk0ms5efp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_175')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   139301970671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970672912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970672720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970673488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301970671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963470544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963470160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301963480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025596432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025595856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025595664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025596624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025598160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025595472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025599120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025598544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025596048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025599888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025599312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025600272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025598736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025597392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025600080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025599504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025598352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025600656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025598928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025601808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025601232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025601424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025601616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025599696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025600464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025603536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025603920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025604496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025603152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025604304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025602576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025605456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025604880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025605072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025605264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025603344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025605840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025604112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025607184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025607568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025604688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025607376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025608144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025605648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025607952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025609104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025608528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025608720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025608912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025606992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025610064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025609488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025607760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025610832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025610256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025611216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025609680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025610640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025611600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025611408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025609872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025610448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025609296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025608336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301025611024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024531664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024531280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024530896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024530512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024532048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024531088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024532816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024535120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024534736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024534928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024535504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024536848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024536656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024535312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024537808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024538000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024539152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024538960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024541072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139301024540304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# ✅ Success! Edge-AI model saved as: agroinsight_mobilenetv3_quantized.tflite
# Downloading to your computer...
